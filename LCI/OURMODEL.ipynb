# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import train_test_split
# Out:
# 2026-01-06 18:34:06.424432: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767724446.622846      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767724446.681761      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767724447.178674      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767724447.178751      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767724447.178755      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767724447.178759      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
print("TF:", tf.__version__)
print("Keras:", keras.__version__)
# Out:
# TF: 2.19.0
# Keras: 3.10.0

# %%
import os
import numpy as np
from skimage.io import imread, imshow, imsave
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import albumentations as A
import random

# Define dataset paths
image_dir = '/kaggle/input/polypdb/PolypDB/PolypDB_modality_wise/LCI/images'
mask_dir = '/kaggle/input/polypdb/PolypDB/PolypDB_modality_wise/LCI/masks'

# Image parameters
IMG_HEIGHT, IMG_WIDTH = 256, 256
CHANNELS = 3
TARGET_SIZE = 600  # Augmented dataset size

# Get sorted file lists
image_files = sorted([f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
mask_files = sorted([f for f in os.listdir(mask_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])

# Check image-mask consistency
if len(image_files) != len(mask_files):
    print(f"Warning: Image-mask count mismatch. Images: {len(image_files)}, Masks: {len(mask_files)}")
else:
    print(f"Found {len(image_files)} image-mask pairs.")

def load_and_preprocess(index):
    """Load, resize, and preprocess an image-mask pair."""
    image_path = os.path.join(image_dir, image_files[index])
    mask_path = os.path.join(mask_dir, mask_files[index])

    image = imread(image_path)
    mask = imread(mask_path, as_gray=True)

    # Ensure correct shape (for RGBA images)
    if image.shape[-1] == 4:
        image = image[:, :, :3]

    image = resize(image, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)
    mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)

    # Convert mask to binary
    mask = (mask > 0.5).astype(np.uint8)

    return (image * 255).astype(np.uint8), mask

# Augmentation Pipelines (Reduced p values for better variation)
aug = A.Compose([
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.Transpose(p=0.5),
    A.GridDistortion(p=0.3),  # Lowered probability
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5)  # Added color augmentation
])

# Augmented dataset directories
img_augmented_path = "/content/Bli_augmented_image"
msk_augmented_path = "/content/BLI_augmented_mask"

# Create directories if they don't exist
os.makedirs(img_augmented_path, exist_ok=True)
os.makedirs(msk_augmented_path, exist_ok=True)

# Load and preprocess images
all_x = []
all_y = []

for count in range(len(image_files)):
    x, y = load_and_preprocess(count)
    all_x.append(x)
    all_y.append(y)

# Convert lists to numpy arrays
all_x = np.array(all_x)
all_y = np.expand_dims(np.array(all_y), axis=-1)  # Add an extra dimension for the mask

# Split dataset (80% train, 10% val, 10% test)
x_train, x_temp, y_train, y_temp = train_test_split(all_x, all_y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# Print dataset shapes
print(f"Training set: {x_train.shape}, {y_train.shape}")
print(f"Validation set: {x_val.shape}, {y_val.shape}")
print(f"Test set: {x_test.shape}, {y_test.shape}")

# Augment the training data (up to TARGET_SIZE)
aug_x_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.uint8)
aug_y_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)

for count in range(TARGET_SIZE):
    index = random.randint(0, len(x_train) - 1)
    image = x_train[index]
    mask = y_train[index, :, :, 0]

    # Augment the image and mask
    augmented = aug(image=image, mask=mask)
    aug_x_train[count] = augmented['image']
    aug_y_train[count, :, :, 0] = augmented['mask']

    # Optionally save augmented images and masks
    new_image_path = os.path.join(img_augmented_path, f"augmented_image_{count}.png")
    new_mask_path = os.path.join(msk_augmented_path, f"augmented_mask_{count}.png")

    imsave(new_image_path, aug_x_train[count])
    imsave(new_mask_path, aug_y_train[count, :, :, 0])
# Combine original and augmented data
final_x_train = np.concatenate((x_train, aug_x_train), axis=0)
final_y_train = np.concatenate((y_train, aug_y_train), axis=0)

# Print the new dataset size
print(f"Final Training set: {final_x_train.shape}, {final_y_train.shape}")

# Optionally shuffle the dataset
indices = np.arange(final_x_train.shape[0])
np.random.shuffle(indices)

final_x_train = final_x_train[indices]
final_y_train = final_y_train[indices]

# Display a sample image and mask
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
imshow(aug_x_train[0])
plt.title("Augmented Image")
plt.subplot(1, 2, 2)
imshow(aug_y_train[0, :, :, 0], cmap='gray')
plt.title("Augmented Mask")
plt.show()
# Out:
# Found 60 image-mask pairs.
# Training set: (48, 256, 256, 3), (48, 256, 256, 1)
# Validation set: (6, 256, 256, 3), (6, 256, 256, 1)
# Test set: (6, 256, 256, 3), (6, 256, 256, 1)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_0.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_1.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_2.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_3.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_4.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_5.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_6.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_7.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_8.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_9.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_10.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_11.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_12.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_13.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_14.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_15.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_16.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_17.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_18.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_19.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_20.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_21.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_22.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_23.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_24.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_25.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_26.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_27.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_28.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_29.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_30.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_31.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_32.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_33.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_34.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_35.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_36.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_37.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_38.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_39.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_40.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_41.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_42.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_43.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_44.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_45.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_46.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_47.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_48.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_49.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_50.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_51.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_52.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_53.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_54.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_55.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_56.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_57.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_58.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_59.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_60.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_61.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_62.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_63.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_64.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_65.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_66.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_67.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_68.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_69.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_70.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_71.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_72.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_73.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_74.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_75.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_76.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_77.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_78.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_79.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_80.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_81.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_82.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_83.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_84.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_85.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_86.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_87.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_88.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_89.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_90.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_91.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_92.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_93.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_94.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_95.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_96.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_97.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_98.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_99.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_100.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_101.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_102.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_103.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_104.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_105.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_106.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_107.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_108.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_109.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_110.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_111.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_112.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_113.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_114.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_115.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_116.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_117.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_118.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_119.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_120.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_121.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_122.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_123.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_124.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_125.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_126.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_127.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_128.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_129.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_130.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_131.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_132.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_133.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_134.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_135.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_136.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_137.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_138.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_139.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_140.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_141.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_142.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_143.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_144.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_145.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_146.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_147.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_148.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_149.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_150.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_151.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_152.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_153.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_154.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_155.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_156.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_157.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_158.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_159.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_160.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_161.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_162.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_163.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_164.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_165.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_166.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_167.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_168.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_169.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_170.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_171.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_172.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_173.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_174.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_175.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_176.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_177.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_178.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_179.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_180.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_181.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_182.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_183.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_184.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_185.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_186.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_187.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_188.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_189.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_190.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_191.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_192.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_193.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_194.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_195.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_196.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_197.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_198.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_199.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_200.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_201.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_202.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_203.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_204.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_205.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_206.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_207.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_208.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_209.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_210.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_211.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_212.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_213.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_214.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_215.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_216.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_217.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_218.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_219.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_220.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_221.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_222.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_223.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_224.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_225.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_226.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_227.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_228.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_229.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_230.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_231.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_232.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_233.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_234.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_235.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_236.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_237.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_238.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_239.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_240.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_241.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_242.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_243.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_244.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_245.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_246.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_247.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_248.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_249.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_250.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_251.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_252.png is a low contrast image
#   return func(*args, **kwargs)
# ...
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_520.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_521.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_522.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_523.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_524.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_525.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_526.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_527.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_528.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_529.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_530.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_531.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_532.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_533.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_534.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_535.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_536.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_537.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_538.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_539.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_540.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_541.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_542.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_543.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_544.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_545.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_546.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_547.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_548.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_549.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_550.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_551.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_552.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_553.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_554.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_555.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_556.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_557.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_558.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_559.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_560.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_561.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_562.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_563.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_564.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_565.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_566.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_567.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_568.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_569.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_570.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_571.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_572.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_573.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_574.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_575.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_576.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_577.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_578.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_579.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_580.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_581.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_582.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_583.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_584.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_585.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_586.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_587.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_588.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_589.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_590.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_591.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_592.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_593.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_594.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_595.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_596.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_597.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_598.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/BLI_augmented_mask/augmented_mask_599.png is a low contrast image
#   return func(*args, **kwargs)
# /tmp/ipykernel_55/1524360492.py:126: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(aug_x_train[0])
# /tmp/ipykernel_55/1524360492.py:129: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(aug_y_train[0, :, :, 0], cmap='gray')
# Final Training set: (648, 256, 256, 3), (648, 256, 256, 1)
# /usr/local/lib/python3.12/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
# Print the shapes
print("final_x_train shape:", final_x_train.shape)
print("final_y_train shape:", final_y_train.shape)
# Out:
# final_x_train shape: (648, 256, 256, 3)
# final_y_train shape: (648, 256, 256, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

IMG_SIZE = 256  # Ensure the output matches this size

def se_block(input_tensor, ratio=16):
    """ Squeeze-and-Excitation Block """
    channels = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(channels // ratio, activation="relu")(se)
    se = Dense(channels, activation="sigmoid")(se)
    se = Reshape((1, 1, channels))(se)
    return Multiply()([input_tensor, se])

def drop_block(x, drop_prob=0.2, block_size=3):
    """ DropBlock Implementation """
    if drop_prob == 0.0:
        return x
    return Dropout(rate=drop_prob)(x)

def unet_efficientnetb4(input_size=(IMG_SIZE, IMG_SIZE, 3)):
    base_model = tf.keras.applications.EfficientNetB4(
        include_top=False,
        weights="imagenet",
        input_shape=input_size
    )

    # Encoder Feature Maps
    s1 = base_model.get_layer("block2a_expand_activation").output  # (64x64, 32)
    s2 = base_model.get_layer("block3a_expand_activation").output  # (32x32, 56)
    s3 = base_model.get_layer("block4a_expand_activation").output  # (16x16, 112)
    s4 = base_model.get_layer("block6a_expand_activation").output  # (8x8, 272)
    b5 = base_model.get_layer("top_activation").output  # (4x4, 1792) Bottleneck

    # Decoder with SE blocks, DropBlock, Dilated Convolutions, and L2 Regularization
    u6 = UpSampling2D(size=(2, 2))(b5)
    u6 = Conv2D(272, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u6)
    u6 = concatenate([u6, s4])
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u6)
    c6 = drop_block(c6)
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c6)
    c6 = se_block(c6)

    u7 = UpSampling2D(size=(2, 2))(c6)
    u7 = Conv2D(112, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u7)
    u7 = concatenate([u7, s3])
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u7)
    c7 = drop_block(c7)
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c7)
    c7 = se_block(c7)

    u8 = UpSampling2D(size=(2, 2))(c7)
    u8 = Conv2D(56, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u8)
    u8 = concatenate([u8, s2])
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u8)
    c8 = drop_block(c8)
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c8)
    c8 = se_block(c8)

    u9 = UpSampling2D(size=(2, 2))(c8)
    u9 = Conv2D(32, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u9)
    u9 = concatenate([u9, s1])
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u9)
    c9 = drop_block(c9)
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c9)
    c9 = se_block(c9)

    u10 = UpSampling2D(size=(2, 2))(c9)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u10)
    c10 = drop_block(c10)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c10)

    # 🚀 Final layer should output (256, 256, 1)
    outputs = Conv2D(1, (1, 1), activation="sigmoid")(c10)  # (256, 256, 1)

    return Model(inputs=base_model.input, outputs=outputs)

model = unet_efficientnetb4()
model.summary()
# Out:
# I0000 00:00:1767724501.981187      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 256, 256,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 256, 256,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 257, 257,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 128, 128,  │      1,296 │ stem_conv_pad[0]… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 128, 128,  │        192 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 128, 128,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 128, 128,  │        432 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 128, 128,  │        192 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 128, 128,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 48)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 48)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 12)  │        588 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 48)  │        624 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 128, 128,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 48)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 128, 128,  │      1,152 │ block1a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 128, 128,  │         96 │ block1a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_dwconv      │ (None, 128, 128,  │        216 │ block1a_project_… │
# │ (DepthwiseConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_bn          │ (None, 128, 128,  │         96 │ block1b_dwconv[0… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_activation  │ (None, 128, 128,  │          0 │ block1b_bn[0][0]  │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_squeeze  │ (None, 24)        │          0 │ block1b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_reshape  │ (None, 1, 1, 24)  │          0 │ block1b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_reduce   │ (None, 1, 1, 6)   │        150 │ block1b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_expand   │ (None, 1, 1, 24)  │        168 │ block1b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_excite   │ (None, 128, 128,  │          0 │ block1b_activati… │
# │ (Multiply)          │ 24)               │            │ block1b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_co… │ (None, 128, 128,  │        576 │ block1b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_bn  │ (None, 128, 128,  │         96 │ block1b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_drop        │ (None, 128, 128,  │          0 │ block1b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_add (Add)   │ (None, 128, 128,  │          0 │ block1b_drop[0][… │
# │                     │ 24)               │            │ block1a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 128, 128,  │      3,456 │ block1b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 128, 128,  │        576 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 128, 128,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 129, 129,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 64, 64,    │      1,296 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 64, 64,    │        576 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 64, 64,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 144)       │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 144) │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 64, 64,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 144)              │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 64, 64,    │      4,608 │ block2a_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 64, 64,    │        128 │ block2a_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 64, 64,    │      6,144 │ block2a_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 64, 64,    │        768 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 64, 64,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 64, 64,    │      1,728 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 64, 64,    │        768 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 64, 64,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 192)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 192) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 64, 64,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 192)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 64, 64,    │      6,144 │ block2b_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 64, 64,    │        128 │ block2b_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 64, 64,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 64, 64,    │          0 │ block2b_drop[0][… │
# │                     │ 32)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_conv │ (None, 64, 64,    │      6,144 │ block2b_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_bn   │ (None, 64, 64,    │        768 │ block2c_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_act… │ (None, 64, 64,    │          0 │ block2c_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_dwconv      │ (None, 64, 64,    │      1,728 │ block2c_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_bn          │ (None, 64, 64,    │        768 │ block2c_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_activation  │ (None, 64, 64,    │          0 │ block2c_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_squeeze  │ (None, 192)       │          0 │ block2c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_reshape  │ (None, 1, 1, 192) │          0 │ block2c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_excite   │ (None, 64, 64,    │          0 │ block2c_activati… │
# │ (Multiply)          │ 192)              │            │ block2c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_co… │ (None, 64, 64,    │      6,144 │ block2c_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_bn  │ (None, 64, 64,    │        128 │ block2c_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_drop        │ (None, 64, 64,    │          0 │ block2c_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_add (Add)   │ (None, 64, 64,    │          0 │ block2c_drop[0][… │
# │                     │ 32)               │            │ block2b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_conv │ (None, 64, 64,    │      6,144 │ block2c_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_bn   │ (None, 64, 64,    │        768 │ block2d_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_act… │ (None, 64, 64,    │          0 │ block2d_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_dwconv      │ (None, 64, 64,    │      1,728 │ block2d_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_bn          │ (None, 64, 64,    │        768 │ block2d_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_activation  │ (None, 64, 64,    │          0 │ block2d_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_squeeze  │ (None, 192)       │          0 │ block2d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_reshape  │ (None, 1, 1, 192) │          0 │ block2d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_excite   │ (None, 64, 64,    │          0 │ block2d_activati… │
# │ (Multiply)          │ 192)              │            │ block2d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_co… │ (None, 64, 64,    │      6,144 │ block2d_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_bn  │ (None, 64, 64,    │        128 │ block2d_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_drop        │ (None, 64, 64,    │          0 │ block2d_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_add (Add)   │ (None, 64, 64,    │          0 │ block2d_drop[0][… │
# │                     │ 32)               │            │ block2c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 64, 64,    │      6,144 │ block2d_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 64, 64,    │        768 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 64, 64,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 67, 67,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 32, 32,    │      4,800 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 32, 32,    │        768 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 32, 32,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 192)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 192) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 192) │      1,728 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 32, 32,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 192)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 32, 32,    │     10,752 │ block3a_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 32, 32,    │        224 │ block3a_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 32, 32,    │     18,816 │ block3a_project_… │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 32, 32,    │      1,344 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 32, 32,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 32, 32,    │      8,400 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 32, 32,    │      1,344 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 32, 32,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 336)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 336) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 336) │      5,040 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 32, 32,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 336)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 32, 32,    │     18,816 │ block3b_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 32, 32,    │        224 │ block3b_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 32, 32,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 32, 32,    │          0 │ block3b_drop[0][… │
# │                     │ 56)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_conv │ (None, 32, 32,    │     18,816 │ block3b_add[0][0] │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_bn   │ (None, 32, 32,    │      1,344 │ block3c_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_act… │ (None, 32, 32,    │          0 │ block3c_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_dwconv      │ (None, 32, 32,    │      8,400 │ block3c_expand_a… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_bn          │ (None, 32, 32,    │      1,344 │ block3c_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_activation  │ (None, 32, 32,    │          0 │ block3c_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_squeeze  │ (None, 336)       │          0 │ block3c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_reshape  │ (None, 1, 1, 336) │          0 │ block3c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block3c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_expand   │ (None, 1, 1, 336) │      5,040 │ block3c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_excite   │ (None, 32, 32,    │          0 │ block3c_activati… │
# │ (Multiply)          │ 336)              │            │ block3c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_co… │ (None, 32, 32,    │     18,816 │ block3c_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_bn  │ (None, 32, 32,    │        224 │ block3c_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_drop        │ (None, 32, 32,    │          0 │ block3c_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_add (Add)   │ (None, 32, 32,    │          0 │ block3c_drop[0][… │
# │                     │ 56)               │            │ block3b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_conv │ (None, 32, 32,    │     18,816 │ block3c_add[0][0] │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_bn   │ (None, 32, 32,    │      1,344 │ block3d_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_act… │ (None, 32, 32,    │          0 │ block3d_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_dwconv      │ (None, 32, 32,    │      8,400 │ block3d_expand_a… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_bn          │ (None, 32, 32,    │      1,344 │ block3d_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_activation  │ (None, 32, 32,    │          0 │ block3d_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_squeeze  │ (None, 336)       │          0 │ block3d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_reshape  │ (None, 1, 1, 336) │          0 │ block3d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block3d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_expand   │ (None, 1, 1, 336) │      5,040 │ block3d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_excite   │ (None, 32, 32,    │          0 │ block3d_activati… │
# │ (Multiply)          │ 336)              │            │ block3d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_project_co… │ (None, 32, 32,    │     18,816 │ block3d_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_project_bn  │ (None, 32, 32,    │        224 │ block3d_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_drop        │ (None, 32, 32,    │          0 │ block3d_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_add (Add)   │ (None, 32, 32,    │          0 │ block3d_drop[0][… │
# │                     │ 56)               │            │ block3c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 32, 32,    │     18,816 │ block3d_add[0][0] │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 32, 32,    │      1,344 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 32, 32,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 33, 33,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 16, 16,    │      3,024 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 16, 16,    │      1,344 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 16, 16,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 336)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 336) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 336) │      5,040 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 16, 16,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 336)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 16, 16,    │     37,632 │ block4a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 16, 16,    │        448 │ block4a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 16, 16,    │     75,264 │ block4a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 16, 16,    │      2,688 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 16, 16,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 16, 16,    │      6,048 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 16, 16,    │      2,688 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 16, 16,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 672)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 672) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 16, 16,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 672)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 16, 16,    │     75,264 │ block4b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 16, 16,    │        448 │ block4b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 16, 16,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 16, 16,    │          0 │ block4b_drop[0][… │
# │                     │ 112)              │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 16, 16,    │     75,264 │ block4b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 16, 16,    │      2,688 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 16, 16,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 16, 16,    │      6,048 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 16, 16,    │      2,688 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 16, 16,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 672)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 672) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 16, 16,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 672)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 16, 16,    │     75,264 │ block4c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 16, 16,    │        448 │ block4c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 16, 16,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 16, 16,    │          0 │ block4c_drop[0][… │
# │                     │ 112)              │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_conv │ (None, 16, 16,    │     75,264 │ block4c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_bn   │ (None, 16, 16,    │      2,688 │ block4d_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_act… │ (None, 16, 16,    │          0 │ block4d_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_dwconv      │ (None, 16, 16,    │      6,048 │ block4d_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_bn          │ (None, 16, 16,    │      2,688 │ block4d_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_activation  │ (None, 16, 16,    │          0 │ block4d_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_squeeze  │ (None, 672)       │          0 │ block4d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_reshape  │ (None, 1, 1, 672) │          0 │ block4d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block4d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_expand   │ (None, 1, 1, 672) │     19,488 │ block4d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_excite   │ (None, 16, 16,    │          0 │ block4d_activati… │
# │ (Multiply)          │ 672)              │            │ block4d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_project_co… │ (None, 16, 16,    │     75,264 │ block4d_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_project_bn  │ (None, 16, 16,    │        448 │ block4d_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# │ (Reshape)           │ 1632)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 68)  │    111,044 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │    112,608 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1632)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 8, 8,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1632)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 8, 8, 448) │    731,136 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 8, 8, 448) │      1,792 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_conv │ (None, 8, 8,      │  1,204,224 │ block7a_project_… │
# │ (Conv2D)            │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_bn   │ (None, 8, 8,      │     10,752 │ block7b_expand_c… │
# │ (BatchNormalizatio… │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_act… │ (None, 8, 8,      │          0 │ block7b_expand_b… │
# │ (Activation)        │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_dwconv      │ (None, 8, 8,      │     24,192 │ block7b_expand_a… │
# │ (DepthwiseConv2D)   │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_bn          │ (None, 8, 8,      │     10,752 │ block7b_dwconv[0… │
# │ (BatchNormalizatio… │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_activation  │ (None, 8, 8,      │          0 │ block7b_bn[0][0]  │
# │ (Activation)        │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_squeeze  │ (None, 2688)      │          0 │ block7b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_reshape  │ (None, 1, 1,      │          0 │ block7b_se_squee… │
# │ (Reshape)           │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_reduce   │ (None, 1, 1, 112) │    301,168 │ block7b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_expand   │ (None, 1, 1,      │    303,744 │ block7b_se_reduc… │
# │ (Conv2D)            │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_excite   │ (None, 8, 8,      │          0 │ block7b_activati… │
# │ (Multiply)          │ 2688)             │            │ block7b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_project_co… │ (None, 8, 8, 448) │  1,204,224 │ block7b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_project_bn  │ (None, 8, 8, 448) │      1,792 │ block7b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_drop        │ (None, 8, 8, 448) │          0 │ block7b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_add (Add)   │ (None, 8, 8, 448) │          0 │ block7b_drop[0][… │
# │                     │                   │            │ block7a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 8, 8,      │    802,816 │ block7b_add[0][0] │
# │                     │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 8, 8,      │      7,168 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 8, 8,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ top_activation[0… │
# │ (UpSampling2D)      │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │    487,696 │ up_sampling2d[0]… │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d[0][0],     │
# │ (Concatenate)       │ 1232)             │            │ block6a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │  3,016,208 │ concatenate[0][0] │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 16,    │          0 │ conv2d_1[0][0]    │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │    666,128 │ dropout[0][0]     │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 272)       │          0 │ conv2d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 17)        │      4,641 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 272)       │      4,896 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 272) │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16, 16,    │          0 │ conv2d_2[0][0],   │
# │                     │ 272)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ multiply[0][0]    │
# │ (UpSampling2D)      │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │     30,576 │ up_sampling2d_1[… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_3[0][0],   │
# │ (Concatenate)       │ 448)              │            │ block4a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    451,696 │ concatenate_1[0]… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    113,008 │ dropout_1[0][0]   │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 112)       │          0 │ conv2d_5[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 7)         │        791 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 112)       │        896 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 112) │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ conv2d_5[0][0],   │
# │ (Multiply)          │ 112)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      6,328 │ up_sampling2d_2[… │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_6[0][0],   │
# │ (Concatenate)       │ 248)              │            │ block3a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │    125,048 │ concatenate_2[0]… │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_7[0][0]    │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     28,280 │ dropout_2[0][0]   │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 56)        │          0 │ conv2d_8[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 3)         │        171 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 56)        │        224 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 56)  │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ conv2d_8[0][0],   │
# │ (Multiply)          │ 56)               │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ multiply_2[0][0]  │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 128,  │      1,824 │ up_sampling2d_3[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_9[0][0],   │
# │ (Concatenate)       │ 176)              │            │ block2a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │     50,720 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_10[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │      9,248 │ dropout_3[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ conv2d_11[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 2)         │         66 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 32)        │         96 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 32)  │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 128, 128,  │          0 │ conv2d_11[0][0],  │
# │ (Multiply)          │ 32)               │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 256, 256,  │          0 │ multiply_3[0][0]  │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │      9,248 │ up_sampling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256, 256,  │          0 │ conv2d_12[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │      9,248 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │         33 │ conv2d_13[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,690,893 (86.56 MB)
#  Trainable params: 22,565,686 (86.08 MB)
#  Non-trainable params: 125,207 (489.09 KB)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def tversky_loss(y_true, y_pred, alpha=0.6, beta=0.4, epsilon=1e-6):
    # Flatten the input tensors
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    # True Positives (TP), False Positives (FP), False Negatives (FN)
    TP = tf.reduce_sum(y_true * y_pred)
    FP = tf.reduce_sum((1 - y_true) * y_pred)
    FN = tf.reduce_sum(y_true * (1 - y_pred))

    # Calculate the Tversky Index
    tversky_index = (TP + epsilon) / (TP + alpha * FP + beta * FN + epsilon)

    # Tversky Loss is the complement of the Tversky Index
    return 1 - tversky_index




# Loss and Metric Functions
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = intersection / (union + 1e-6)
    return 1 - iou

def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    y_true = tf.cast(y_true, tf.float32)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    loss = alpha * tf.pow(1 - y_pred, gamma) * bce
    return loss

# %%
def combo_loss(y_true, y_pred, dice_weight=0.3, bce_weight=0.2,iou_weight=0.2,tversky_weight=0.3, pos_weight=7.0, neg_weight=1.0):
    y_true = tf.cast(y_true, tf.float32)

    # Dice Loss
    dice = dice_loss(y_true, y_pred)

    # Binary Cross-Entropy (Weighted)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    weighted_bce = pos_weight * y_true * bce + neg_weight * (1 - y_true) * bce

    # IoU Loss
    iou = iou_loss(y_true, y_pred)

    # Tversky Loss (For Imbalance)
    tversky = tversky_loss(y_true, y_pred)

    # Compute final loss with weights
    return (dice_weight * dice +
            bce_weight * tf.reduce_mean(weighted_bce) + iou_weight * iou + tversky_weight * tversky
            )

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import Adam


# Define Adam optimizer with an initial learning rate
initial_lr = 1e-4
optimizer = Adam(learning_rate=initial_lr)


def lr_schedule(epoch, lr):
    if epoch < 5:  # Warmup phase
        return lr * 1.5  # Increase LR to stabilize training
    elif epoch < 30:
        return lr * 0.98  # Gradual decay
    else:
        return lr * 0.95  # Final stabilization

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
import tensorflow.keras.backend as K

smooth = 1


def iou(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return intersection / (union + 1e-6)
# Create the metric objects outside the functions
prec = tf.keras.metrics.Precision()
rec = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 2 * ((p * r) / (p + r + 1e-6))

def f2_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 5 * ((p * r) / ((4 * p) + r + 1e-6))

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))  # Cast y_true to float32
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# In your model.compile call:
model.compile(optimizer=optimizer, loss=combo_loss, metrics=[iou,dice_coef, f1_score, f2_score, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define Adam optimizer with an initial learning rate
initial_lr = 1e-4
optimizer = Adam(learning_rate=initial_lr)

# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss
    factor=0.5,          # Reduce LR by half
    patience=5,          # Wait 5 epochs before reducing LR
    verbose=1,           # Print message when LR is reduced
    min_lr=1e-6          # Minimum LR limit
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,            # Stop if no improvement for 5 epochs
    restore_best_weights=True  # Restore best model weights
)

# Compile the model (assuming bce_dice_loss, iou, f1_score, etc., are defined)
# model.compile(optimizer=Adam(learning_rate=1e-4), loss=bce_dice_loss, metrics=[iou, f1_score, f2_score, Precision(), Recall()])

# Train the model with Early Stopping
history = model.fit(
    final_x_train, final_y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=8,
    callbacks=[early_stopping,lr_scheduler]  # Add the Early Stopping callback
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767724578.207026     122 service.cc:152] XLA service 0x7d8c600038c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767724578.207069     122 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1767724590.680073     122 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-01-06 18:36:52.320392: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-06 18:36:52.504984: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-06 18:36:52.830349: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-06 18:36:53.029853: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-06 18:36:53.531465: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-06 18:36:53.758785: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1767724666.458354     122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 198s 421ms/step - dice_coef: 0.1097 - f1_score: 0.0738 - f2_score: 0.0909 - iou: 0.0642 - loss: 0.9829 - precision_1: 0.1087 - recall_1: 0.1669 - val_dice_coef: 0.5837 - val_f1_score: 0.5823 - val_f2_score: 0.7510 - val_iou: 0.4121 - val_loss: 0.5472 - val_precision_1: 0.4237 - val_recall_1: 0.9308 - learning_rate: 1.5000e-04
# Epoch 2/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - dice_coef: 0.6583 - f1_score: 0.6718 - f2_score: 0.6989 - iou: 0.5032 - loss: 0.4716 - precision_1: 0.6540 - recall_1: 0.7329 - val_dice_coef: 0.8366 - val_f1_score: 0.8406 - val_f2_score: 0.7833 - val_iou: 0.7192 - val_loss: 0.2823 - val_precision_1: 0.9573 - val_recall_1: 0.7493 - learning_rate: 2.2500e-04
# Epoch 3/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - dice_coef: 0.8700 - f1_score: 0.8749 - f2_score: 0.8706 - iou: 0.7729 - loss: 0.2548 - precision_1: 0.8999 - recall_1: 0.8708 - val_dice_coef: 0.8655 - val_f1_score: 0.8678 - val_f2_score: 0.8993 - val_iou: 0.7629 - val_loss: 0.2545 - val_precision_1: 0.8200 - val_recall_1: 0.9215 - learning_rate: 3.3750e-04
# Epoch 4/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - dice_coef: 0.8977 - f1_score: 0.9011 - f2_score: 0.8949 - iou: 0.8164 - loss: 0.2174 - precision_1: 0.9215 - recall_1: 0.8986 - val_dice_coef: 0.9112 - val_f1_score: 0.9168 - val_f2_score: 0.9396 - val_iou: 0.8369 - val_loss: 0.1968 - val_precision_1: 0.8812 - val_recall_1: 0.9555 - learning_rate: 5.0625e-04
# Epoch 5/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - dice_coef: 0.8974 - f1_score: 0.9014 - f2_score: 0.9009 - iou: 0.8185 - loss: 0.2131 - precision_1: 0.9182 - recall_1: 0.8873 - val_dice_coef: 0.6134 - val_f1_score: 0.6152 - val_f2_score: 0.7820 - val_iou: 0.4424 - val_loss: 0.5068 - val_precision_1: 0.4538 - val_recall_1: 0.9547 - learning_rate: 7.5938e-04
# Epoch 6/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - dice_coef: 0.9190 - f1_score: 0.9215 - f2_score: 0.9185 - iou: 0.8524 - loss: 0.1833 - precision_1: 0.9373 - recall_1: 0.9148 - val_dice_coef: 0.9205 - val_f1_score: 0.9221 - val_f2_score: 0.9226 - val_iou: 0.8527 - val_loss: 0.1726 - val_precision_1: 0.9213 - val_recall_1: 0.9229 - learning_rate: 7.4419e-04
# Epoch 7/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - dice_coef: 0.9459 - f1_score: 0.9477 - f2_score: 0.9431 - iou: 0.8981 - loss: 0.1439 - precision_1: 0.9622 - recall_1: 0.9409 - val_dice_coef: 0.9364 - val_f1_score: 0.9384 - val_f2_score: 0.9480 - val_iou: 0.8803 - val_loss: 0.1444 - val_precision_1: 0.9229 - val_recall_1: 0.9545 - learning_rate: 7.2930e-04
# Epoch 8/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - dice_coef: 0.9541 - f1_score: 0.9557 - f2_score: 0.9534 - iou: 0.9128 - loss: 0.1245 - precision_1: 0.9650 - recall_1: 0.9534 - val_dice_coef: 0.9228 - val_f1_score: 0.9240 - val_f2_score: 0.9504 - val_iou: 0.8567 - val_loss: 0.1527 - val_precision_1: 0.8831 - val_recall_1: 0.9689 - learning_rate: 7.1472e-04
# Epoch 9/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - dice_coef: 0.9593 - f1_score: 0.9606 - f2_score: 0.9602 - iou: 0.9220 - loss: 0.1114 - precision_1: 0.9663 - recall_1: 0.9609 - val_dice_coef: 0.9082 - val_f1_score: 0.9101 - val_f2_score: 0.9512 - val_iou: 0.8319 - val_loss: 0.1619 - val_precision_1: 0.8490 - val_recall_1: 0.9807 - learning_rate: 7.0042e-04
# Epoch 10/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9592 - f1_score: 0.9605 - f2_score: 0.9607 - iou: 0.9226 - loss: 0.1045 - precision_1: 0.9646 - recall_1: 0.9621 - val_dice_coef: 0.8974 - val_f1_score: 0.8991 - val_f2_score: 0.9378 - val_iou: 0.8139 - val_loss: 0.1733 - val_precision_1: 0.8412 - val_recall_1: 0.9655 - learning_rate: 6.8641e-04
# Epoch 11/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - dice_coef: 0.9424 - f1_score: 0.9442 - f2_score: 0.9414 - iou: 0.8925 - loss: 0.1250 - precision_1: 0.9557 - recall_1: 0.9399 - val_dice_coef: 0.9294 - val_f1_score: 0.9302 - val_f2_score: 0.9375 - val_iou: 0.8680 - val_loss: 0.1338 - val_precision_1: 0.9183 - val_recall_1: 0.9425 - learning_rate: 6.7269e-04
# Epoch 12/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - dice_coef: 0.9650 - f1_score: 0.9662 - f2_score: 0.9652 - iou: 0.9325 - loss: 0.0939 - precision_1: 0.9718 - recall_1: 0.9655 - val_dice_coef: 0.9579 - val_f1_score: 0.9584 - val_f2_score: 0.9619 - val_iou: 0.9192 - val_loss: 0.0954 - val_precision_1: 0.9527 - val_recall_1: 0.9642 - learning_rate: 6.5923e-04
# Epoch 13/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9673 - f1_score: 0.9684 - f2_score: 0.9674 - iou: 0.9368 - loss: 0.0848 - precision_1: 0.9724 - recall_1: 0.9686 - val_dice_coef: 0.9079 - val_f1_score: 0.9092 - val_f2_score: 0.9512 - val_iou: 0.8313 - val_loss: 0.1475 - val_precision_1: 0.8468 - val_recall_1: 0.9815 - learning_rate: 6.4605e-04
# Epoch 14/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9688 - f1_score: 0.9699 - f2_score: 0.9688 - iou: 0.9396 - loss: 0.0785 - precision_1: 0.9753 - recall_1: 0.9689 - val_dice_coef: 0.9244 - val_f1_score: 0.9254 - val_f2_score: 0.9498 - val_iou: 0.8594 - val_loss: 0.1251 - val_precision_1: 0.8874 - val_recall_1: 0.9669 - learning_rate: 6.3313e-04
# Epoch 15/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9733 - f1_score: 0.9743 - f2_score: 0.9732 - iou: 0.9481 - loss: 0.0701 - precision_1: 0.9789 - recall_1: 0.9741 - val_dice_coef: 0.8659 - val_f1_score: 0.8671 - val_f2_score: 0.9272 - val_iou: 0.7635 - val_loss: 0.1865 - val_precision_1: 0.7825 - val_recall_1: 0.9722 - learning_rate: 6.2046e-04
# Epoch 16/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9722 - f1_score: 0.9732 - f2_score: 0.9718 - iou: 0.9461 - loss: 0.0680 - precision_1: 0.9787 - recall_1: 0.9724 - val_dice_coef: 0.7649 - val_f1_score: 0.7651 - val_f2_score: 0.8786 - val_iou: 0.6193 - val_loss: 0.2978 - val_precision_1: 0.6297 - val_recall_1: 0.9749 - learning_rate: 6.0806e-04
# Epoch 17/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - dice_coef: 0.9744 - f1_score: 0.9755 - f2_score: 0.9750 - iou: 0.9502 - loss: 0.0632 - precision_1: 0.9788 - recall_1: 0.9762 - val_dice_coef: 0.9206 - val_f1_score: 0.9209 - val_f2_score: 0.9560 - val_iou: 0.8528 - val_loss: 0.1236 - val_precision_1: 0.8679 - val_recall_1: 0.9809 - learning_rate: 5.9589e-04
# Epoch 18/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9765 - f1_score: 0.9774 - f2_score: 0.9764 - iou: 0.9541 - loss: 0.0586 - precision_1: 0.9806 - recall_1: 0.9768 - val_dice_coef: 0.9221 - val_f1_score: 0.9231 - val_f2_score: 0.9550 - val_iou: 0.8554 - val_loss: 0.1187 - val_precision_1: 0.8745 - val_recall_1: 0.9775 - learning_rate: 5.8398e-04
# Epoch 19/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - dice_coef: 0.9767 - f1_score: 0.9775 - f2_score: 0.9768 - iou: 0.9545 - loss: 0.0565 - precision_1: 0.9811 - recall_1: 0.9779 - val_dice_coef: 0.9590 - val_f1_score: 0.9594 - val_f2_score: 0.9664 - val_iou: 0.9213 - val_loss: 0.0747 - val_precision_1: 0.9480 - val_recall_1: 0.9711 - learning_rate: 5.7230e-04
# Epoch 20/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9752 - f1_score: 0.9762 - f2_score: 0.9749 - iou: 0.9516 - loss: 0.0573 - precision_1: 0.9809 - recall_1: 0.9757 - val_dice_coef: 0.9500 - val_f1_score: 0.9508 - val_f2_score: 0.9542 - val_iou: 0.9047 - val_loss: 0.0830 - val_precision_1: 0.9453 - val_recall_1: 0.9564 - learning_rate: 5.6085e-04
# Epoch 21/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9741 - f1_score: 0.9750 - f2_score: 0.9734 - iou: 0.9497 - loss: 0.0564 - precision_1: 0.9796 - recall_1: 0.9739 - val_dice_coef: 0.9496 - val_f1_score: 0.9504 - val_f2_score: 0.9643 - val_iou: 0.9041 - val_loss: 0.0824 - val_precision_1: 0.9282 - val_recall_1: 0.9738 - learning_rate: 5.4963e-04
# Epoch 22/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9784 - f1_score: 0.9792 - f2_score: 0.9780 - iou: 0.9578 - loss: 0.0504 - precision_1: 0.9838 - recall_1: 0.9787 - val_dice_coef: 0.9343 - val_f1_score: 0.9348 - val_f2_score: 0.9604 - val_iou: 0.8766 - val_loss: 0.0991 - val_precision_1: 0.8952 - val_recall_1: 0.9782 - learning_rate: 5.3864e-04
# Epoch 23/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9781 - f1_score: 0.9790 - f2_score: 0.9783 - iou: 0.9572 - loss: 0.0493 - precision_1: 0.9824 - recall_1: 0.9788 - val_dice_coef: 0.9349 - val_f1_score: 0.9348 - val_f2_score: 0.9528 - val_iou: 0.8777 - val_loss: 0.0960 - val_precision_1: 0.9063 - val_recall_1: 0.9652 - learning_rate: 5.2787e-04
# Epoch 24/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9772 - f1_score: 0.9780 - f2_score: 0.9768 - iou: 0.9555 - loss: 0.0489 - precision_1: 0.9818 - recall_1: 0.9771 - val_dice_coef: 0.9209 - val_f1_score: 0.9222 - val_f2_score: 0.9583 - val_iou: 0.8533 - val_loss: 0.1130 - val_precision_1: 0.8676 - val_recall_1: 0.9840 - learning_rate: 5.1731e-04
# Epoch 25/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9765 - f1_score: 0.9773 - f2_score: 0.9769 - iou: 0.9541 - loss: 0.0489 - precision_1: 0.9803 - recall_1: 0.9779 - val_dice_coef: 0.9268 - val_f1_score: 0.9279 - val_f2_score: 0.9573 - val_iou: 0.8636 - val_loss: 0.1040 - val_precision_1: 0.8826 - val_recall_1: 0.9780 - learning_rate: 5.0696e-04
# Epoch 26/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9787 - f1_score: 0.9794 - f2_score: 0.9790 - iou: 0.9583 - loss: 0.0458 - precision_1: 0.9823 - recall_1: 0.9801 - val_dice_coef: 0.9473 - val_f1_score: 0.9479 - val_f2_score: 0.9444 - val_iou: 0.8999 - val_loss: 0.0774 - val_precision_1: 0.9537 - val_recall_1: 0.9421 - learning_rate: 4.9683e-04
# Epoch 27/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9770 - f1_score: 0.9778 - f2_score: 0.9764 - iou: 0.9551 - loss: 0.0466 - precision_1: 0.9823 - recall_1: 0.9774 - val_dice_coef: 0.9379 - val_f1_score: 0.9389 - val_f2_score: 0.9602 - val_iou: 0.8831 - val_loss: 0.0898 - val_precision_1: 0.9054 - val_recall_1: 0.9750 - learning_rate: 4.8689e-04
# Epoch 28/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9794 - f1_score: 0.9801 - f2_score: 0.9795 - iou: 0.9598 - loss: 0.0431 - precision_1: 0.9831 - recall_1: 0.9801 - val_dice_coef: 0.9439 - val_f1_score: 0.9447 - val_f2_score: 0.9669 - val_iou: 0.8937 - val_loss: 0.0821 - val_precision_1: 0.9099 - val_recall_1: 0.9822 - learning_rate: 4.7715e-04
# Epoch 29/50
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - dice_coef: 0.9791 - f1_score: 0.9799 - f2_score: 0.9793 - iou: 0.9592 - loss: 0.0430 - precision_1: 0.9834 - recall_1: 0.9802 - val_dice_coef: 0.9426 - val_f1_score: 0.9432 - val_f2_score: 0.9649 - val_iou: 0.8914 - val_loss: 0.0834 - val_precision_1: 0.9093 - val_recall_1: 0.9798 - learning_rate: 4.6761e-04

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()
def plot_loss(history):
    plt.figure(figsize=(8, 6))

    # Plot training & validation loss
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Val Loss', color='red')

    # Labels and title
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# Call the function after training
plot_loss(history)

# %%
y_pred = model.predict(x_test)  # Predict masks for test images
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step

# %%
y_pred_thresholded = (y_pred > 0.5).astype(np.uint8)  # Convert probability map to binary mask

# %%
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
print("y_pred shape:", y_pred.shape)
print("y_pred_thresholded shape:", y_pred_thresholded.shape)
# Out:
# x_test shape: (6, 256, 256, 3)
# y_test shape: (6, 256, 256, 1)
# y_pred shape: (6, 256, 256, 1)
# y_pred_thresholded shape: (6, 256, 256, 1)

# %%
import matplotlib.pyplot as plt
import random

# Select a random test image
index = random.randint(0, len(x_test) - 1)

plt.figure(figsize=(15, 5))

# Original test image
plt.subplot(1, 3, 1)
plt.imshow(x_test[index])
plt.title("Test Image")

# Ground truth mask
plt.subplot(1, 3, 2)
plt.imshow(y_test[index, :, :, 0], cmap='gray')
plt.title("Ground Truth Mask")

# Predicted mask (thresholded)
plt.subplot(1, 3, 3)
plt.imshow(y_pred_thresholded[index, :, :, 0], cmap='gray')
plt.title("Predicted Mask")

plt.show()

# %%
import tensorflow as tf
import numpy as np

# Lists to store scores
dice_scores = []
iou_scores = []

# Initialize the Keras Precision and Recall metrics
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Loop through each test sample
for i in range(len(y_test)):
    # Convert to float32 before calculation
    y_true = y_test[i].astype(np.float32)
    y_pred = y_pred_thresholded[i].astype(np.float32)

    # Calculate Dice, IoU, Precision, and Recall for each sample
    dice = dice_coef(y_true, y_pred)
    iou_score = iou(y_true, y_pred)  # Assuming iou is your IoU function

    # Update the Precision and Recall metrics
    precision_metric.update_state(y_true, y_pred)
    recall_metric.update_state(y_true, y_pred)

    # Append scores
    dice_scores.append(dice)
    iou_scores.append(iou_score)

# Final Precision and Recall after iterating through all test samples
mean_precision = precision_metric.result().numpy()
mean_recall = recall_metric.result().numpy()

# Calculate mean scores
mean_dice = np.mean(dice_scores)
mean_iou = np.mean(iou_scores)

# Compute F1 and F2 scores
if mean_precision + mean_recall > 0:
    f1_score = 2 * (mean_precision * mean_recall) / (mean_precision + mean_recall)
    f2_score = 5 * (mean_precision * mean_recall) / (4 * mean_precision + mean_recall)
else:
    f1_score, f2_score = 0.0, 0.0  # Avoid division by zero

# Print results
print(f"Mean Dice Score: {mean_dice:.4f}")
print(f"Mean IoU Score: {mean_iou:.4f}")
print(f"Mean Precision: {mean_precision:.4f}")
print(f"Mean Recall: {mean_recall:.4f}")


print(f"F1 Score: {f1_score:.4f}")
print(f"F2 Score: {f2_score:.4f}")
# Out:
# Mean Dice Score: 0.9339
# Mean IoU Score: 0.8770
# Mean Precision: 0.9183
# Mean Recall: 0.9486
# F1 Score: 0.9332
# F2 Score: 0.9424

# %%
# =====================================================
# IMPORTS
# =====================================================
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import csv

# =====================================================
# PARAMETERS
# =====================================================
THRESHOLD = 0.5
BASE_DIR = "/kaggle/working/visual"

IMG_DIR  = os.path.join(BASE_DIR, "images")
GT_DIR   = os.path.join(BASE_DIR, "ground_truth")
PRED_DIR = os.path.join(BASE_DIR, "predictions")
COMP_DIR = os.path.join(BASE_DIR, "comparisons")
CSV_FILE = os.path.join(BASE_DIR, "metrics.csv")

# Create directories
os.makedirs(IMG_DIR, exist_ok=True)
os.makedirs(GT_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(COMP_DIR, exist_ok=True)

# =====================================================
# PREDICT & THRESHOLD
# =====================================================
y_pred = model.predict(x_test, batch_size=1, verbose=1)
y_pred_bin = (y_pred > THRESHOLD).astype(np.uint8)

# =====================================================
# INITIALIZE CSV
# =====================================================
with open(CSV_FILE, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow([
        "Image_Index",
        "Precision",
        "Recall",
        "F2",
        "Dice",
        "IoU"
    ])

# =====================================================
# METRIC FUNCTION
# =====================================================
def compute_metrics(y_true, y_pred):
    y_true = y_true.astype(np.uint8)
    y_pred = y_pred.astype(np.uint8)

    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))

    precision = TP / (TP + FP + 1e-6)
    recall    = TP / (TP + FN + 1e-6)
    f2        = 5 * precision * recall / (4 * precision + recall + 1e-6)
    dice      = 2 * TP / (2 * TP + FP + FN + 1e-6)
    iou       = TP / (TP + FP + FN + 1e-6)

    return precision, recall, f2, dice, iou

# =====================================================
# METRICS STORAGE FOR MEAN
# =====================================================
dice_scores = []
iou_scores  = []
precision_metric = tf.keras.metrics.Precision()
recall_metric    = tf.keras.metrics.Recall()

# =====================================================
# LOOP THROUGH ALL TEST IMAGES
# =====================================================
for i in range(len(x_test)):

    # ------------------- DATA -------------------
    img  = x_test[i]
    gt   = y_test[i, :, :, 0].astype(np.uint8)
    pred = y_pred_bin[i, :, :, 0].astype(np.uint8)

    # ------------------- METRICS -------------------
    precision, recall, f2, dice, iou = compute_metrics(gt, pred)

    # Update metrics for mean
    dice_scores.append(dice)
    iou_scores.append(iou)
    precision_metric.update_state(gt, pred)
    recall_metric.update_state(gt, pred)

    # ------------------- SAVE CSV -------------------
    with open(CSV_FILE, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([i+1, precision, recall, f2, dice, iou])

    # ------------------- SAVE IMAGES -------------------
    plt.imsave(os.path.join(IMG_DIR, f"image_{i+1}.png"), img)
    plt.imsave(os.path.join(GT_DIR, f"gt_{i+1}.png"), gt, cmap='gray')
    plt.imsave(os.path.join(PRED_DIR, f"pred_{i+1}.png"), pred, cmap='gray')

    # ------------------- DISPLAY COMPARISON -------------------
    plt.figure(figsize=(15,5))
    plt.subplot(1,3,1)
    plt.imshow(img)
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.imshow(gt, cmap="gray")
    plt.title("Ground Truth")
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.imshow(pred, cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.tight_layout()
    plt.show()
    plt.savefig(os.path.join(COMP_DIR, f"comparison_{i+1}.png"), dpi=300)
    plt.close()

# =====================================================
# FINAL MEAN METRICS
# =====================================================
mean_precision = precision_metric.result().numpy()
mean_recall    = recall_metric.result().numpy()
mean_dice      = np.mean(dice_scores)
mean_iou       = np.mean(iou_scores)
mean_f2        = 5 * mean_precision * mean_recall / (4 * mean_precision + mean_recall + 1e-6)

print("========== FINAL RESULTS ==========")
print(f"Mean Dice       : {mean_dice:.4f}")
print(f"Mean IoU        : {mean_iou:.4f}")
print(f"Mean Precision  : {mean_precision:.4f}")
print(f"Mean Recall     : {mean_recall:.4f}")
print(f"Mean F2 Score   : {mean_f2:.4f}")

print(f"\nAll results saved in: {BASE_DIR}")
print(f"CSV metrics saved as: {CSV_FILE}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step
# ========== FINAL RESULTS ==========
# Mean Dice       : 0.9339
# Mean IoU        : 0.8770
# Mean Precision  : 0.9183
# Mean Recall     : 0.9486
# Mean F2 Score   : 0.9424
#
# All results saved in: /kaggle/working/visual
# CSV metrics saved as: /kaggle/working/visual/metrics.csv

# %%
import pandas as pd
import numpy as np

# =====================================================
# CALCULATE POLYP AREA RATIO FOR EACH PREDICTED MASK
# =====================================================
areas = [np.sum(y_pred_thresholded[i]) / (y_pred_thresholded[i].shape[0]*y_pred_thresholded[i].shape[1])
         for i in range(len(y_pred_thresholded))]

# =====================================================
# DEFINE SIZE THRESHOLDS (ADAPTIVE)
# =====================================================
small_thr = np.percentile(areas, 25)
medium_thr = np.percentile(areas, 75)

def polyp_size(area):
    if area <= small_thr:
        return "Small"
    elif area <= medium_thr:
        return "Medium"
    else:
        return "Large"

size_labels = [polyp_size(a) for a in areas]

# =====================================================
# CREATE DATAFRAME WITH METRICS
# =====================================================
df = pd.DataFrame({
    "Dice": dice_scores,
    "IoU": iou_scores,
    "Precision": [mean_precision]*len(dice_scores),  # or use per-image Precision if available
    "Recall": [mean_recall]*len(dice_scores),        # or per-image Recall if available
    "F1": [f1_score]*len(dice_scores),
    "F2": [f2_score]*len(dice_scores),
    "Area_Ratio": areas,
    "Polyp_Size": size_labels
})

# =====================================================
# SAVE CSVs PER SIZE
# =====================================================
CSV_DIR = "/kaggle/working/metrics_by_size"
os.makedirs(CSV_DIR, exist_ok=True)

for size in ["Small", "Medium", "Large"]:
    df_size = df[df["Polyp_Size"] == size]
    df_size.to_csv(f"{CSV_DIR}/{size.lower()}_metrics.csv", index=False)

# =====================================================
# COMPUTE MEAN METRICS PER SIZE
# =====================================================
mean_metrics_by_size = df.groupby("Polyp_Size")[["Dice","IoU","Precision","Recall","F1","F2"]].mean()
print("========== MEAN METRICS PER POLYP SIZE ==========")
print(mean_metrics_by_size)
# Out:
# ========== MEAN METRICS PER POLYP SIZE ==========
#                 Dice       IoU  Precision    Recall        F1        F2
# Polyp_Size
# Large       0.917413  0.847539    0.91826  0.948598  0.933183  0.942371
# Medium      0.940426  0.888748    0.91826  0.948598  0.933183  0.942371
# Small       0.943750  0.894686    0.91826  0.948598  0.933183  0.942371

# %%
import zipfile
import os

# Directory where the per-size CSVs are saved
CSV_DIR = "/kaggle/working/metrics_by_size"

# Output zip file
zip_filename = "/kaggle/working/polyp_metrics_by_size.zip"

with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for root, _, files in os.walk(CSV_DIR):
        for file in files:
            if file.endswith(".csv"):
                file_path = os.path.join(root, file)
                zipf.write(file_path, arcname=file)  # arcname avoids nested folders

print(f"All per-size CSVs zipped into: {zip_filename}")
# Out:
# All per-size CSVs zipped into: /kaggle/working/polyp_metrics_by_size.zip

# %%
import shutil

# Folder you want to zip
folder_to_zip = "/kaggle/working/visual"

# Output zip file path
output_zip = "/kaggle/working/visual.zip"

# Create the zip file
shutil.make_archive(base_name=output_zip.replace(".zip",""), format='zip', root_dir=folder_to_zip)

print(f"✅ Zipped folder saved as: {output_zip}")
# Out:
# ✅ Zipped folder saved as: /kaggle/working/visual.zip

# %%
model.save('/kaggle/working/ourmodel.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# ======================================================
# WHITE PIXEL ANALYSIS
# ======================================================
def white_pixel_percentage(mask):
    return (np.sum(mask == 1) / mask.size) * 100

white_per_test_image = [white_pixel_percentage(y_pred_bin[i, :, :, 0]) for i in range(len(y_pred_bin))]

# ======================================================
# CLASSIFY POLYPS BY SIZE (ADAPTIVE)
# ======================================================
areas = [np.sum(mask) / (mask.shape[0]*mask.shape[1]) for mask in y_pred_bin]

small_thr  = np.percentile(areas, 25)
medium_thr = np.percentile(areas, 75)

def polyp_size_adaptive(area):
    if area <= small_thr:
        return "Small"
    elif area <= medium_thr:
        return "Medium"
    else:
        return "Large"

size_labels = [polyp_size_adaptive(a) for a in areas]

small_idx  = [i for i, s in enumerate(size_labels) if s == "Small"]
medium_idx = [i for i, s in enumerate(size_labels) if s == "Medium"]
large_idx  = [i for i, s in enumerate(size_labels) if s == "Large"]

print(f"Small polyps: {len(small_idx)}, Medium polyps: {len(medium_idx)}, Large polyps: {len(large_idx)}")

# ======================================================
# OPTIONAL: BOX PLOT OF WHITE PIXEL % PER SIZE
# ======================================================
small_values  = [white_per_test_image[i] for i in small_idx]
medium_values = [white_per_test_image[i] for i in medium_idx]
large_values  = [white_per_test_image[i] for i in large_idx]

plt.figure(figsize=(8,5))
plt.boxplot([small_values, medium_values, large_values], labels=["Small", "Medium", "Large"])
plt.ylabel("White Pixel %")
plt.title("Polyp Size vs White Pixel % Distribution (Predicted Masks)")
plt.show()
# Out:
# Small polyps: 2, Medium polyps: 2, Large polyps: 2
# /tmp/ipykernel_55/1024428488.py:41: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([small_values, medium_values, large_values], labels=["Small", "Medium", "Large"])

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score
import tensorflow.keras.backend as K

# ======================================================
# DICE AND IoU FUNCTIONS
# ======================================================
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(tf.cast(y_pred, tf.float32))
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# ======================================================
# COMPUTE METRICS FOR ONE SAMPLE
# ======================================================
def compute_metrics(y_true, y_pred):
    dice = dice_coef(y_true, y_pred).numpy()  # convert from tensor to float
    iou_score = iou(y_true, y_pred).numpy()
    precision = precision_score(y_true.flatten(), y_pred.flatten())
    recall = recall_score(y_true.flatten(), y_pred.flatten())
    
    return {
        "Dice": dice,
        "IoU": iou_score,
        "Precision": precision,
        "Sensitivity": recall
    }

# ======================================================
# COMPUTE METRICS FOR A POLYP SIZE GROUP
# ======================================================
def metrics_by_group(indices, group_name):
    dice_list = []
    iou_list  = []
    prec_list = []
    rec_list  = []
    f2_list   = []

    for i in indices:
        # Ensure float32 input for dice/iou
        y_true = y_test[i, :, :, 0].astype(np.float32)
        y_pred = y_pred_bin[i, :, :, 0].astype(np.float32)
        
        metrics = compute_metrics(y_true, y_pred)
        
        dice_list.append(metrics["Dice"])
        iou_list.append(metrics["IoU"])
        prec_list.append(metrics["Precision"])
        rec_list.append(metrics["Sensitivity"])
        
        # Compute F2 score
        P = metrics["Precision"]
        R = metrics["Sensitivity"]
        f2 = 5 * (P * R) / (4*P + R) if (4*P + R) > 0 else 0.0
        f2_list.append(f2)

    print(f"=== {group_name} Polyps ===")
    print(f"Count: {len(indices)}")
    print(f"Mean Dice      : {np.mean(dice_list):.4f}")
    print(f"Mean IoU       : {np.mean(iou_list):.4f}")
    print(f"Mean Precision : {np.mean(prec_list):.4f}")
    print(f"Mean Recall    : {np.mean(rec_list):.4f}")
    print(f"Mean F2 Score  : {np.mean(f2_list):.4f}\n")
    
    return {
        "Dice": dice_list,
        "IoU": iou_list,
        "Precision": prec_list,
        "Recall": rec_list,
        "F2": f2_list
    }

# ======================================================
# COMPUTE METRICS FOR SMALL, MEDIUM, LARGE
# ======================================================
small_metrics  = metrics_by_group(small_idx, "Small")
medium_metrics = metrics_by_group(medium_idx, "Medium")
large_metrics  = metrics_by_group(large_idx, "Large")
# Out:
# === Small Polyps ===
# Count: 2
# Mean Dice      : 0.9438
# Mean IoU       : 0.8947
# Mean Precision : 0.9336
# Mean Recall    : 0.9562
# Mean F2 Score  : 0.9509
#
# === Medium Polyps ===
# Count: 2
# Mean Dice      : 0.9404
# Mean IoU       : 0.8887
# Mean Precision : 0.9694
# Mean Recall    : 0.9131
# Mean F2 Score  : 0.9239
#
# === Large Polyps ===
# Count: 2
# Mean Dice      : 0.9174
# Mean IoU       : 0.8475
# Mean Precision : 0.8741
# Mean Recall    : 0.9653
# Mean F2 Score  : 0.9455

# %%
# ======================================================
# BOX PLOT OF DICE SCORES PER POLYP SIZE
# ======================================================
plt.figure(figsize=(8,5))
plt.boxplot([small_metrics["Dice"], medium_metrics["Dice"], large_metrics["Dice"]],
            labels=["Small", "Medium", "Large"])
plt.ylabel("Dice Score")
plt.title("Dice Score Distribution per Polyp Size")
plt.show()

# Optional: Also show IoU distribution
plt.figure(figsize=(8,5))
plt.boxplot([small_metrics["IoU"], medium_metrics["IoU"], large_metrics["IoU"]],
            labels=["Small", "Medium", "Large"])
plt.ylabel("IoU Score")
plt.title("IoU Score Distribution per Polyp Size")
plt.show()
# Out:
# /tmp/ipykernel_55/3076438329.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([small_metrics["Dice"], medium_metrics["Dice"], large_metrics["Dice"]],
# /tmp/ipykernel_55/3076438329.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([small_metrics["IoU"], medium_metrics["IoU"], large_metrics["IoU"]],

# %%
# ======================================================
# BOX PLOT OF PRECISION SCORES PER POLYP SIZE
# ======================================================
plt.figure(figsize=(8,5))
plt.boxplot([small_metrics["Precision"], medium_metrics["Precision"], large_metrics["Precision"]],
            labels=["Small", "Medium", "Large"])
plt.ylabel("Precision")
plt.title("Precision Distribution per Polyp Size")
plt.show()

# ======================================================
# BOX PLOT OF RECALL SCORES PER POLYP SIZE
# ======================================================
plt.figure(figsize=(8,5))
plt.boxplot([small_metrics["Recall"], medium_metrics["Recall"], large_metrics["Recall"]],
            labels=["Small", "Medium", "Large"])
plt.ylabel("Recall")
plt.title("Recall Distribution per Polyp Size")
plt.show()

# ======================================================
# Out:
# /tmp/ipykernel_55/810366704.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([small_metrics["Precision"], medium_metrics["Precision"], large_metrics["Precision"]],
# /tmp/ipykernel_55/810366704.py:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([small_metrics["Recall"], medium_metrics["Recall"], large_metrics["Recall"]],

# %%
# ======================================================
# COMPUTE F2 SCORE PER IMAGE (ADD TO METRICS DICT)
# ======================================================
beta = 2
eps = 1e-6

for metrics in [small_metrics, medium_metrics, large_metrics]:
    metrics["F2"] = [
        (1 + beta**2) * p * r / (beta**2 * p + r + eps)
        for p, r in zip(metrics["Precision"], metrics["Recall"])
    ]

# %%
# ======================================================
# BOX PLOT OF F2 SCORES PER POLYP SIZE
# ======================================================
plt.figure(figsize=(8,5))
plt.boxplot(
    [small_metrics["F2"], medium_metrics["F2"], large_metrics["F2"]],
    labels=["Small", "Medium", "Large"]
)
plt.ylabel("F2 Score")
plt.title("F2 Score Distribution per Polyp Size")
plt.show()
# Out:
# /tmp/ipykernel_55/217268936.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
plt.figure(figsize=(20,5))

metrics = ["Dice", "IoU", "Precision", "Recall", "F2"]
titles  = ["Dice", "IoU", "Precision", "Recall", "F2 Score"]

for i, (m, t) in enumerate(zip(metrics, titles), 1):
    plt.subplot(1, 5, i)
    plt.boxplot(
        [small_metrics[m], medium_metrics[m], large_metrics[m]],
        labels=["Small", "Medium", "Large"]
    )
    plt.ylabel(t)
    plt.title(t)

plt.suptitle("Segmentation Performance Across Polyp Sizes", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_55/2775314682.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/2775314682.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/2775314682.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/2775314682.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/2775314682.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
import os
import matplotlib.pyplot as plt
import zipfile

# ======================================================
# CONFIG
# ======================================================
plot_dir = "/kaggle/working/plot"
os.makedirs(plot_dir, exist_ok=True)

metrics = {
    "Dice": "Dice Score",
    "IoU": "IoU Score",
    "Precision": "Precision",
    "Recall": "Recall",
    "F2": "F2 Score"
}

# ======================================================
# SAVE INDIVIDUAL METRIC PLOTS
# ======================================================
for metric, ylabel in metrics.items():
    plt.figure(figsize=(8,5))
    plt.boxplot(
        [small_metrics[metric], medium_metrics[metric], large_metrics[metric]],
        labels=["Small", "Medium", "Large"]
    )
    plt.ylabel(ylabel)
    plt.title(f"{ylabel} Distribution per Polyp Size")
    
    save_path = os.path.join(plot_dir, f"{metric.lower()}_boxplot.png")
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.close()
# Out:
# /tmp/ipykernel_55/3281966515.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/3281966515.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/3281966515.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/3281966515.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/3281966515.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
# ======================================================
# SAVE COMBINED METRIC PLOT
# ======================================================
plt.figure(figsize=(20,5))

metrics_list = ["Dice", "IoU", "Precision", "Recall", "F2"]
titles = ["Dice", "IoU", "Precision", "Recall", "F2 Score"]

for i, (m, t) in enumerate(zip(metrics_list, titles), 1):
    plt.subplot(1, 5, i)
    plt.boxplot(
        [small_metrics[m], medium_metrics[m], large_metrics[m]],
        labels=["Small", "Medium", "Large"]
    )
    plt.ylabel(t)
    plt.title(t)

plt.suptitle("Segmentation Performance Across Polyp Sizes", fontsize=14)
plt.tight_layout()

combined_path = os.path.join(plot_dir, "combined_metrics_boxplot.png")
plt.savefig(combined_path, dpi=300, bbox_inches="tight")
plt.close()
# Out:
# /tmp/ipykernel_55/648338950.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/648338950.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/648338950.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/648338950.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /tmp/ipykernel_55/648338950.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
zip_filename = "/kaggle/working/plot.zip"

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(plot_dir):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, arcname=file)

print("✅ All plots saved and zipped:")
print(zip_filename)
# Out:
# ✅ All plots saved and zipped:
# /kaggle/working/plot.zip
